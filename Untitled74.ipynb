# %%
import numpy

# %%
l = [1,2,3,4,5]
np.mean(l)
# Out:
# 3.0

# %%
np.median(l)
# Out:
# 3.0

# %%
Q1 = np.quantile(a = l , q = 0.25)
Q1
# Out:
# 2.0

# %%
Q3 = np.quantile(a = l , q = 0.75)
Q3
# Out:
# 4.0

# %%
0.75*15
# Out:
# 11.25

# %%
((1000 - 3000) ** 2) + ((2000 - 3000) ** 2 ) + ((4000 - 3000) ** 2) + ((5000 - 3000)**2)
# Out:
# 10000000

# %%
10000000/5
# Out:
# 2000000.0

# %%
l1 = [1,2,3,4,5]
l2 = [0,5,2,-1,4]
l3 = [0,-1,-2,0.5,2]
np.corrcoef([l1,l2,l3])
# Out:
# array([[ 1.        ,  0.12403473,  0.57341464],
#        [ 0.12403473,  1.        , -0.03232879],
#        [ 0.57341464, -0.03232879,  1.        ]])

# %%
! pip install pandas
